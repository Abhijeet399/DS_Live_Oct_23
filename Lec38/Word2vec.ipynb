# %%
import gensim

# %%
from gensim import models

# %%
model = models.KeyedVectors.load_word2vec_format("C:/Users/bhatt/Downloads/GoogleNews-vectors-negative300.bin.gz", binary = True)

# %%
print(len(model['King']))
# Out:
# 300

# %%
model['Pen']
# Out:
# array([-1.63085938e-01,  8.00781250e-02, -2.02148438e-01, -1.08886719e-01,
#         9.17968750e-02,  2.22656250e-01, -2.79296875e-01,  2.08984375e-01,
#         1.44531250e-01, -3.93066406e-02,  3.44238281e-02,  3.27148438e-02,
#         1.33789062e-01,  7.27539062e-02, -8.54492188e-02, -9.47265625e-02,
#         2.35351562e-01,  1.87500000e-01, -1.33789062e-01, -1.53320312e-01,
#        -3.22265625e-02, -1.67968750e-01,  1.24511719e-01, -1.72119141e-02,
#        -1.01562500e-01, -1.91650391e-02, -6.49414062e-02, -4.41894531e-02,
#         9.42382812e-02,  6.59179688e-02,  5.85937500e-02, -5.32226562e-02,
#        -2.00195312e-01,  1.07421875e-01,  1.60156250e-01,  3.77655029e-04,
#         1.57226562e-01,  6.93359375e-02,  1.42578125e-01, -2.58789062e-02,
#        -1.97753906e-02,  3.71093750e-02, -1.34765625e-01, -1.13281250e-01,
#         8.39843750e-02, -5.61523438e-02, -1.16210938e-01, -1.93359375e-01,
# ...

# %%
model.most_similar(positive = ['king', 'woman'], negative = ['man'])

# %%
model.most_similar('Cat')
